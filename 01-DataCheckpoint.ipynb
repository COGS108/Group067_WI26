# %% [markdown]
# # COGS 108 - Data Checkpoint
#
# ## Authors

# %% [markdown]
# - Aditi Bansal: Background and prior work and Dataset and cleaning
# - Deepal Deleena:  Dataset and cleaning and research question
# - Rowan Brougham: Hypothesis and Team expectations
# - Mahi Agrawal: Ethics and Privacy and updated timeline
# - Hetvi Majmudar: Ethics and Privacy

# %% [markdown]
# ## Research Question

# %% [markdown]
# What combinations of academic credentials (undergraduate GPA and GMAT score) and professional experience (years of work experience and prior industry) are most strongly associated with MBA admission outcomes (Admit vs. Non-Admit) in the Wharton Class of 2025 dataset?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# MBA admissions decisions are inherently multifactorial, combining academic performance, standardized test scores, and professional experience to evaluate an applicant’s readiness and potential. Top programs such as Wharton explicitly emphasize holistic review processes, where quantitative metrics are considered alongside work experience, leadership trajectory, and academic background. As a result, applicants are rarely evaluated based on a single credential; instead, admissions outcomes reflect how multiple factors interact within an applicant’s overall profile.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1)
#
# Prior research has consistently examined the role of academic metrics in MBA admissions and performance. A large meta-analysis by Kuncel et al. found that standardized tests such as the GMAT are moderately predictive of graduate academic success, particularly in quantitatively rigorous programs, while undergraduate GPA reflects sustained academic effort over time.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) However, the study also emphasized that test scores and GPA alone are insufficient to fully explain student outcomes, motivating broader evaluation frameworks that include professional experience and contextual factors.
#
# Professional experience has been identified as another key component of MBA admissions decisions. Reports from the Graduate Management Admission Council (GMAC) indicate that years of work experience and industry background are used by admissions committees to assess leadership potential, maturity, and career progression.<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3) These reports suggest that applicants with fewer years of experience may still be competitive if they demonstrate strong academic preparation, while applicants with extensive work experience may offset weaker academic indicators. This supports the idea that combinations of credentials matter more than any single variable.
#
# In applied data science contexts, several publicly available projects have analyzed MBA admissions datasets using exploratory data analysis and predictive modeling. For example, Kaggle-based projects examining MBA admissions data commonly use logistic regression and subgroup analysis to explore relationships between GPA, GMAT scores, work experience, and admission outcomes.<a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4) These projects often find evidence of interaction effects, such as high GMAT scores compensating for lower GPA or work experience strengthening applications from non-traditional academic backgrounds. Building on this prior work, the present project focuses specifically on identifying which combinations of academic credentials and work experience are most strongly associated with admission in the Wharton Class of 2025 dataset.
#
# While prior research and applied analyses provide useful insight into MBA admissions patterns, several limitations and threats to validity are worth noting. Many admissions-related datasets, including the Wharton Class of 2025 dataset used in this project, are synthetic or incomplete representations of real admissions processes, limiting causal interpretation of results.<a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5) Additionally, key qualitative factors such as essays, recommendation letters, and interviews—often emphasized by admissions committees—are not captured in structured datasets, potentially overstating the influence of measurable variables like GPA, GMAT scores, and work experience. Prior studies also caution that standardized test performance and academic metrics may reflect access to resources rather than underlying leadership or managerial potential, underscoring the importance of distinguishing evidence-based findings from admissions rhetoric when interpreting results.<a name="cite_ref-2b"></a>[<sup>2</sup>](#cite_note-2)
#
# ---
#
# ### References
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Wharton School. *How Wharton Selects Its MBA Class*.
# https://mba.wharton.upenn.edu/admissions/
#
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Kuncel, N. R., Hezlett, S. A., & Ones, D. S. (2007). *A comprehensive meta-analysis of the predictive validity of graduate admissions tests*. *Psychological Bulletin*.
# https://pubmed.ncbi.nlm.nih.gov/11271753
#
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Graduate Management Admission Council (GMAC). *Factors in the MBA Admissions Decision*.
# https://www.gmac.com/market-intelligence-and-research/research-library
#
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Kaggle. *MBA Admission Dataset and Related Analyses (Class of 2025)*.
# https://www.kaggle.com/datasets/taweilo/mba-admission-dataset
#
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5) Dawes, R. M. (1979). *The robust beauty of improper linear models in decision making*. *American Psychologist*.
# https://psycnet.apa.org/record/1979-30170-001

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# Hypothesis 1:
# Applicants in the Wharton Class of 2025 dataset who demonstrate both strong academic credentials (signified by: higher undergraduate GPA and higher GMAT/GRE scores) and strong professional experience (signified by: more years of full-time work, higher position within companies, at stronger companies) will have the highest probability of admission. Applicants who are strong in only academics or only work experience will be less likely to be admitted than those who show strength in both areas.
#
# Rationale:
# Wharton is one of the most competitive MBA programs. Their applicant are likely among the most successful, so having both strong academic and professional experience will make for a stronger application. Strong academic performance shows preparation for the quantitative and analytical rigor of the program, while leadership experience shows future career potential.
#
#
# Hypothesis 2:
# Applicants with relatively weaker academic credentials (lower GPA or test scores) may still have competitive admission chances if they have exceptional professional experience, such as prestigious employers, entrepreneurial success, or significant leadership accomplishments.
#
# Rationale:
# It's a business school at the end of the day. Some people don't necessarily do well in school but are extremely successful people. Some people are also late bloomers, so they only recently started working very hard. Therefore, we believe lower academic credentials can sometimes be compensated for by strong professional experience.

# %% [markdown]
# ## Data

# %%
### Data overview

# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/taweilo/mba-admission-dataset/main/mba_admission.csv', 'filename':'mba_admission.csv'},
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/bad-drivers/bad-drivers.csv', 'filename':'bad-drivers.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')

# %% [markdown]
# ### Online Shoppers Purchasing Intention Dataset (Real World Data)
#
# - **Dataset Name:** Online Shoppers Purchasing Intention Dataset (Real world data)
# - **Link to the dataset:** https://archive.ics.uci.edu/dataset/468/online+shoppers+purchasing+intention+dataset
# - **Number of observations:** 12,330 sessions
# - **Number of variables:** 18 variables
#
# - **Description of the variables most relevant to this project:**
#
# - The dataset used in this project is the Online Shoppers Purchasing Intention Dataset obtained from the UCI Machine Learning Repository.
#
# - It contains 12,330 observations, where each row represents a single user session on an e-commerce website.
#
# - The dataset includes 18 variables that describe browsing behavior, session context, and whether the session resulted in a purchase (Revenue).
#
# - Because the data is session-level rather than user-level, each observation reflects one visit to the website rather than long-term customer behavior.
#
# - The most important metrics in this dataset relate to browsing engagement and purchase intent. Page visit variables such as Administrative, Informational, and ProductRelated measure the number of pages viewed in each category (unit: page counts).
#
# - Corresponding duration variables (e.g., ProductRelated_Duration) measure time spent on those pages in seconds.
#
# - BounceRates and ExitRates are proportions between 0 and 1 that represent the likelihood of leaving the website after viewing a page; values closer to 1 indicate higher likelihood of exiting.
#
# - PageValues represents the estimated monetary value of a page based on historical transaction data, with higher values suggesting stronger purchase intent.
#
# - SpecialDay ranges from 0 to 1 and represents how close the session occurred to a special shopping day (e.g., holidays), where values closer to 1 indicate proximity to that event.
#
# - The target variable, Revenue, is binary (1 = purchase occurred, 0 = no purchase).
#
# - One potential concern with this dataset is that it originates from a single e-commerce platform, meaning results may not generalize to all online shopping environments.
#
# - Additionally, the dataset is session-based rather than customer-based, so repeat visitors may appear multiple times without being explicitly linked across sessions.
#
# - The dataset is also class imbalanced, with only about 15% of sessions resulting in a purchase, which may influence predictive modeling performance.
#
# - Finally, contextual variables such as income level, product type, and marketing campaigns are not included, limiting causal interpretation.

# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv('data/00-raw/mba_admission.csv')

# Display first few rows
df.head()

# Show dataset size
print('Dataset shape:', df.shape)

# Check missing values
print('\nMissing values by column:')
print(df.isna().sum())

# Clean admission column (null means Deny)
df['admission'] = df['admission'].fillna('Deny')

# Check numeric ranges
print('\nSummary statistics:')
print(df[['gpa', 'gmat', 'work_exp']].describe())

# Flag potential outliers
print('\nInvalid GPA values:')
print(df[(df['gpa'] < 0) | (df['gpa'] > 4)])

print('\nInvalid GMAT values:')
print(df[(df['gmat'] < 200) | (df['gmat'] > 800)])

print('\nInvalid work experience values:')
print(df[df['work_exp'] < 0])

# Save cleaned dataset
df.to_csv('data/02-processed/mba_admission_clean.csv', index=False)

# %% [markdown]
# ### Data Cleaning Decisions
#
# Null values in the `admission` column represent denied applications according to the dataset documentation. These values were recoded as "Deny" to make admission outcomes explicit and ensure consistency for later analysis.
#
# This transformation does not alter the distribution of outcomes but simply makes implicit denials explicit.
#
# We verified that GPA values fall within [0, 4], GMAT scores within [200, 800], and work experience is non-negative. Any values outside these theoretical bounds would be flagged as data entry errors. No invalid values were retained in the cleaned dataset.
#
# Aside from the admission column (where null indicated Deny), we assessed missingness across all variables. Because missingness was minimal and not structurally patterned, we proceeded with complete-case analysis for regression models.
#
# Industry and undergraduate major were treated as categorical predictors and converted to dummy/indicator variables for regression modeling.

# %% [markdown]
# ## Ethics

# %% [markdown]
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > We will make sure the dataset was obtained with proper consent or public-use authorization, and that our use of it follows all licensing requirements and institutional guidelines.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > Admissions data often reflect structural and socioeconomic inequalities rather than purely merit-based outcomes. Applicants from elite universities, well-funded industries, or strong professional networks may be overrepresented, while those from underrepresented or nontraditional backgrounds may be left out, leading to sampling bias and historical bias that can reinforce unfair conclusions or stereotypes.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > Using admissions and applicant-level academic and professional data creates important ethical and privacy concerns, especially around confidentiality. Even if personally identifiable information is removed, certain combinations of credentials, employment history, and demographic attributes can still make it possible to re-identify individuals. To reduce this risk, we will rely only on anonymized data and share results only in aggregate form.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# >  We will check the data for imbalances across available demographic and background variables and run fairness checks to see whether patterns differ across groups.
#
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# > The data will be stored safely with limited access and used specifically for this academic analysis.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
# > Because the dataset is anonymized and publicly authorized for use, individual removal requests are not applicable, and we will not attempt to identify or trace any individuals.
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > The dataset will be used only for this project and will not be retained or reused beyond the scope of the course.
#
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# > Admissions data may not fully capture qualitative or contextual factors influencing outcomes, which may limit interpretation and fairness in conclusions.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > We will monitor bias by conducting checks before analysis, during modeling, and after results are generated to identify any imbalances or systematic disparities.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# > Results will be described as correlational, not causal, to avoid overstating their meaning.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# > We will follow all terms of use and report findings only in aggregate form so that no individual-level information is exposed.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > Any biases we find will be clearly documented, and limitations will be explained to ensure transparency and responsible interpretation.
#
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# > We will take care not to frame the results as prescriptive guidelines for admissions decisions, to reduce the risk of misuse or unintended harm. We will also clearly explain limitations and potential harms so the findings are used responsibly and do not disadvantage specific populations.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# > We will take care not to frame the results as prescriptive guidelines for admissions decisions, to reduce the risk of misuse or unintended harm. We will also clearly explain limitations and potential harms so the findings are used responsibly and do not disadvantage specific populations.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > We will take care not to frame the results as prescriptive guidelines for admissions decisions, to reduce the risk of misuse or unintended harm. We will also clearly explain limitations and potential harms so the findings are used responsibly and do not disadvantage specific populations.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# > We will take care not to frame the results as prescriptive guidelines for admissions decisions, to reduce the risk of misuse or unintended harm. We will also clearly explain limitations and potential harms so the findings are used responsibly and do not disadvantage specific populations.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > We will take care not to frame the results as prescriptive guidelines for admissions decisions, to reduce the risk of misuse or unintended harm. We will also clearly explain limitations and potential harms so the findings are used responsibly and do not disadvantage specific populations.
#
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [ ] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# Team Structure & Organization
#
# - Team will communicate on WhatsApp, and try to respond to tasks and messages within 12 hours.
# - Finish assignments way before the deadline, and have a group meeting before that deadline
# - Be able to review each other's work and be open to feedback
# - Everyone should be consistent and cohesive instead of doing work too individually and being fragmented.
# - We hope to have a fair division of work. We plan to do this by delegating in calls and deciding what is fair as a group.
#
# Extenuating Circumstances
#
# - If things come up, such as being sick, be clear and communicate with the group, and we can work together to pick up the slack
#
# Tone, Professionalism, & Conflict Resolution
#
# - Hasn’t been an issue yet, but if there are conflicts in this regard, we hope to have a safe environment that allows people to explain how they feel. Hopefully, we will be able to handle it internally.
# - In the event that there is a serious conflict that cannot be resolved within our group, we will escalate it to the professor and TAs.
#
# Decision Making
#
# - In the event that we cannot decide on a major decision, we will decide via majority vote.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 1/31  |  6 PM | Review project guidelines and rubric; Propose 2–3 research questions per person; Identify candidate datasets and key variables | Select final research question and clearly define dependent/independent variables; Formulate testable hypothesis; Decide communication workflow and file structure; Assign background research responsibilities |
# | 2/4  |  1 PM |  Conduct literature review; Draft proposal sections; Inspect candidate datasets for size, structure, and relevance | Compare datasets using defined criteria (sample size, missingness, variable alignment); Select dataset with documented rationale; Refine hypothesis to match available variables; Identify potential confounders and ethical considerations; Finalize internal deadlines |
# | 2/11  | 1 PM  | Import dataset into notebook; Inspect structure and summary statistics; Identify missing values, inconsistencies, and outliers; Begin cleaning | Review and justify cleaning decisions (handling NaNs, filtering rows, renaming variables); Confirm final analysis-ready variables; Outline initial analytical approaches (e.g., regression, group comparison); Assign responsibilities for wrangling, diagnostics, modeling, and visualization   |
# | 2/18  | 6 PM  | Complete structured data wrangling; Generate summary statistics and preliminary visualizations; Conduct exploratory analysis aligned with research question | Validate EDA findings and ensure reproducibility; Confirm which variables enter baseline model; Define model comparison plan (e.g., baseline vs. adjusted model); Decide evaluation metrics (e.g., R², RMSE, classification accuracy if applicable); Identify required plots for interpretation (e.g., regression plots, distributions, residuals)   |
# | 2/25  | 1 PM  | Fit initial models individually; Generate diagnostic plots and performance metrics; Document preliminary interpretations | Compare baseline vs. adjusted models using R², RMSE, and AIC; select final model based on fit and interpretability; Evaluate statistical significance and effect sizes; Check assumptions using residual and diagnostic plots; Decide which models and visualizations will be included in final report; Complete project check-in |
# | 3/4  | 6 PM  | Complete assigned analysis sections; Draft results, discussion, and conclusion; Prepare finalized visualizations | Review alignment between hypothesis, methods, and results; Refine interpretation to distinguish statistical vs. practical significance; Ensure figures directly support conclusions; Edit for clarity, logical flow, and methodological transparency |
# | 3/11  | Before 11:59 PM  | Conduct full notebook review; Re-run analysis from start to confirm reproducibility; Finalize formatting and citations | Perform rubric-based checklist review; Confirm all analysis steps are justified and clearly explained; Submit final project; Complete group surveys |
